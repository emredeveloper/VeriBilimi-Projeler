# %% [markdown]
# <a href="https://colab.research.google.com/github/emredeveloper/VeriBilimi-Projeler/blob/main/Yolo11_Model_Video_Object_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

# %%
import cv2

from ultralytics import solutions

cap = cv2.VideoCapture("/content/cats.mp4")
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Define region points
region_points = [(20, 400), (1080, 404), (1080, 360), (20, 360)]

# Video writer
video_writer = cv2.VideoWriter("object_counting_output.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# Init Object Counter
counter = solutions.ObjectCounter(
    show=True,
    region=region_points,
    model="yolo11n.pt",
)

# Process video
while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    im0 = counter.count(im0)
    video_writer.write(im0)

cap.release()
video_writer.release()
cv2.destroyAllWindows()
# Out:
# Ultralytics Solutions: ✅ {'model': 'yolo11n.pt', 'region': [(20, 400), (1080, 404), (1080, 360), (20, 360)], 'line_width': 2, 'show': True, 'show_in': True, 'show_out': True, 'classes': None, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'colormap': None}
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# 0: 640x384 1 cat, 670.0ms
# Speed: 4.1ms preprocess, 670.0ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cat, 223.0ms
# Speed: 9.7ms preprocess, 223.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cat, 209.9ms
# Speed: 5.9ms preprocess, 209.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cat, 212.9ms
# Speed: 4.7ms preprocess, 212.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 cat, 232.0ms
# Speed: 5.3ms preprocess, 232.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# ...

# %%
import cv2
from IPython.display import display, HTML

# Specify the path to the video file
video_path = '/content/object_counting_output.avi'

# Read the video file using OpenCV
cap = cv2.VideoCapture(video_path)

# Check if the video file was opened successfully
if not cap.isOpened():
    print("Error: Unable to open video file.")
else:
    # Create an HTML video element to display the video
    html = """
    <video width="800" height="600" controls>
      <source src="{}" type="video/avi">
      Your browser does not support the video tag.
    </video>
    """.format(video_path)

    # Display the HTML video element
    display(HTML(html))
# Out:
#     <video width="800" height="600" controls>
#       <source src="/content/object_counting_output.avi" type="video/avi">
#       Your browser does not support the video tag.
#     </video>

# %%
import cv2
from IPython.display import Video

# Specify the path to the video file
video_path = '/content/object_counting_output.avi'

# Read the video file using OpenCV
cap = cv2.VideoCapture(video_path)

# Check if the video file was opened successfully
if not cap.isOpened():
    print("Error: Unable to open video file.")
else:
    # Display the video file using IPython's Video class
    video = Video(video_path, width=800, height=600)
    display(video)
# Out:
# <video src="/content/object_counting_output.avi" controls  width="800"  height="600">
#       Your browser does not support the <code>video</code> element.
#     </video>
