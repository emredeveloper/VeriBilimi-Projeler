# %%
import matplotlib.pyplot as plt   #ilgili kütüphaneleri import ettim
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('2019.csv')    #verileri açtım

# %%
data
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
data.isnull()
# Out:
#      Overall rank  Country or region  Score  GDP per capita  Social support  \
# 0           False              False  False           False           False
# 1           False              False  False           False           False
# 2           False              False  False           False           False
# 3           False              False  False           False           False
# 4           False              False  False           False           False
# ..            ...                ...    ...             ...             ...
# 151         False              False  False           False           False
# 152         False              False  False           False           False
# 153         False              False  False           False           False
# 154         False              False  False           False           False
# 155         False              False  False           False           False
#
# ...

# %%
data.columns = data.columns.str.replace(' ', '_')

# %%
data
# Out:
#      Overall_rank         Country_or_region  Score  GDP_per_capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social_support  Healthy_life_expectancy  Freedom_to_make_life_choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
#correlation map
f,ax = plt.subplots(figsize=(12,12)) #tablomuzun boyutu
sns.heatmap(data.corr(), annot= True, linewidths= .5, fmt='.2f', ax= ax)
# Out:
# <AxesSubplot:>

# %%
data.index
# Out:
# RangeIndex(start=0, stop=156, step=1)

# %%
data.columns
# Out:
# Index(['Overall_rank', 'Country_or_region', 'Score', 'GDP_per_capita',
#        'Social_support', 'Healthy_life_expectancy',
#        'Freedom_to_make_life_choices', 'Generosity',
#        'Perceptions_of_corruption'],
#       dtype='object')

# %%
data.plot(kind='scatter', x='GDP_per_capita', y='Social_support', alpha=0.5, color= 'red', figsize=(5,5))
# Out:
# <AxesSubplot:xlabel='GDP_per_capita', ylabel='Social_support'>

# %%
Turkey = data["Country_or_region"] == 'Turkey'
data[Turkey]
# Out:
#     Overall_rank Country_or_region  Score  GDP_per_capita  Social_support  \
# 78            79            Turkey  5.373           1.183            1.36
#
#     Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# 78                    0.808                         0.195       0.083
#
#     Perceptions_of_corruption
# 78                      0.106

# %%
z = data['Perceptions_of_corruption']<0.02
data[z]
# Out:
#      Overall_rank       Country_or_region  Score  GDP_per_capita  \
# 37             38                Slovakia  6.198           1.246
# 38             39       Trinidad & Tobago  6.192           1.231
# 45             46                  Kosovo  6.100           0.882
# 47             48                 Romania  6.070           1.162
# 70             71                 Moldova  5.529           0.685
# 77             78  Bosnia and Herzegovina  5.386           0.945
# 96             97                Bulgaria  5.011           1.092
# 132           133                 Ukraine  4.332           0.820
#
#      Social_support  Healthy_life_expectancy  Freedom_to_make_life_choices  \
# 37            1.504                    0.881                         0.334
# 38            1.477                    0.713                         0.489
# 45            1.232                    0.758                         0.489
# 47            1.232                    0.825                         0.462
# ...

# %%
data.sort_values("Perceptions_of_corruption", ascending=False).head(10)      #büyükten küçüğe belli bir kolon değeri için sıralama
# Out:
#      Overall_rank Country_or_region  Score  GDP_per_capita  Social_support  \
# 33             34         Singapore  6.262           1.572           1.463
# 151           152            Rwanda  3.334           0.359           0.711
# 1               2           Denmark  7.600           1.383           1.573
# 0               1           Finland  7.769           1.340           1.587
# 7               8       New Zealand  7.307           1.303           1.557
# 6               7            Sweden  7.343           1.387           1.487
# 5               6       Switzerland  7.480           1.452           1.526
# 2               3            Norway  7.554           1.488           1.582
# 13             14        Luxembourg  7.090           1.609           1.479
# 15             16           Ireland  7.021           1.499           1.553
#
#      Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# ...

# %%
data[(data['GDP_per_capita']>1.000) & (data['Perceptions_of_corruption']<0.05)]
# Out:
#     Overall_rank  Country_or_region  Score  GDP_per_capita  Social_support  \
# 19            20     Czech Republic  6.852           1.269           1.487
# 35            36              Italy  6.223           1.294           1.488
# 37            38           Slovakia  6.198           1.246           1.504
# 38            39  Trinidad & Tobago  6.192           1.231           1.477
# 41            42          Lithuania  6.149           1.238           1.515
# 47            48            Romania  6.070           1.162           1.232
# 48            49             Cyprus  6.046           1.263           1.223
# 51            52           Thailand  6.008           1.050           1.409
# 61            62            Hungary  5.758           1.201           1.410
# 65            66           Portugal  5.693           1.221           1.431
# 67            68             Russia  5.648           1.183           1.452
# ...

# %%
for index,value in data[['Freedom_to_make_life_choices']][150:].iterrows():
    print(index," : ",value)
# Out:
# 150  :  Freedom_to_make_life_choices    0.143
# Name: 150, dtype: float64
# 151  :  Freedom_to_make_life_choices    0.555
# Name: 151, dtype: float64
# 152  :  Freedom_to_make_life_choices    0.417
# Name: 152, dtype: float64
# 153  :  Freedom_to_make_life_choices    0.0
# Name: 153, dtype: float64
# 154  :  Freedom_to_make_life_choices    0.225
# Name: 154, dtype: float64
# 155  :  Freedom_to_make_life_choices    0.01
# Name: 155, dtype: float64
